# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

from parser import CountTableParser
from quality_check import QuarityChecker
from ctlLibAnalysis import CtlLibAnalyzer

label_path='../data/pilotLib_label.tsv'
mpra_path='../data/pilotLib_lintiMPRA.tsv'
cnt_path='../data/pilotLib_ATACandCnT.tsv'

ct=CountTableParser(label_path, mpra_path=mpra_path,cnt_path=cnt_path)
qc=QuarityChecker(ct)
batch=CtlLibAnalyzer(ct)
# Out:
# INFO:parser:Loaded sample labels: 400 samples
# INFO:parser:Loaded MPRA data: 1197 entries
# INFO:parser:Loaded ATAC and CUT&Tag data: 1200 entries
# INFO:parser:Processing MPRA data...
# INFO:parser:Processing ATAC and CUT&Tag data...
# INFO:parser:Processing completed successfully

# %%
qc.plot_barcode_coverage_distribution()

# %%
qc.plot_umi_count_distribution(logx=True,logy=False)

# %%
qc.plot_umi_correlation(log=True)

# %%
qc.plot_logFC_correlation()

# %%
qc.plot_activity_correlation()

# %%
batch.plot_activity_distribution()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# 1 vs. 2: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.128e-01 U_stat=2.187e+03
# 1 vs. 3: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:5.365e-18 U_stat=3.240e+02
# 1 vs. 4: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:4.826e-05 U_stat=1.840e+03
# 1 vs. 5: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:7.504e-18 U_stat=1.000e+00
# 1 vs. 6: Mann-Whitney-Wilcoxon test two-sided with Benjamini-Hochberg correction, P_val:2.380e-07 U_stat=5.000e+02
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# ...

# %%
endogenous_path='../data/pilotLib_endogenous_normCoverages.tsv'

batch.load_endogenous_data(endogenous_path)
batch.plot_activity_correlation('ATAC','eg_ATAC')
